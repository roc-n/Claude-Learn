# %%
# Install depends
# %pip install anthropic python-dotenv
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Requirement already satisfied: anthropic in d:\env\python\lib\site-packages (0.75.0)
# Requirement already satisfied: python-dotenv in d:\env\python\lib\site-packages (1.2.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in d:\env\python\lib\site-packages (from anthropic) (3.7.0)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\env\python\lib\site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in d:\env\python\lib\site-packages (from anthropic) (0.17.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in d:\env\python\lib\site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in d:\env\python\lib\site-packages (from anthropic) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in d:\env\python\lib\site-packages (from anthropic) (2.1.1)
# Requirement already satisfied: sniffio in d:\env\python\lib\site-packages (from anthropic) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.10 in d:\env\python\lib\site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in d:\env\python\lib\site-packages (from anyio<5,>=3.5.0->anthropic) (3.4)
# Requirement already satisfied: exceptiongroup in d:\env\python\lib\site-packages (from anyio<5,>=3.5.0->anthropic) (1.1.1)
# Requirement already satisfied: certifi in d:\env\python\lib\site-packages (from httpx<1,>=0.25.0->anthropic) (2023.5.7)
# Requirement already satisfied: httpcore==1.* in d:\env\python\lib\site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in d:\env\python\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.4.0 in d:\env\python\lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.5.0)
# Requirement already satisfied: pydantic-core==2.4.0 in d:\env\python\lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (2.4.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Load environment variables
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from anthropic import Anthropic
import os
from openai import OpenAI


api_key = os.getenv("ANTHROPIC_API_KEY")

client = Anthropic(
    base_url="https://api.laozhang.ai/v1/chat/completions",
    api_key=api_key
)
model = "claude-sonnet-4-20250514"

# %%
import requests

url = "https://api.laozhang.ai/v1/chat/completions"

api_key = os.getenv("ANTHROPIC_API_KEY")
headers = {
    "Content-Type": "application/json",
    "Authorization": api_key
}
# data = {
#     "model": "claude-sonnet-4-20250514",
#     "stream": False,
#     "messages": [
#         {"role": "user", "content": "What is quantum computing? Answer in one sentence."}
#     ]
# }
# response = requests.post(url, headers=headers, json=data)
# answer = response.json()['choices'][0]['message']['content']
# print(answer)


# second request using anthropic library
# data = {
#     "model": "claude-sonnet-4-20250514",
#     "stream": False,
#     "messages": [
#         {"role": "user", "content": "Write another sentence."}
#     ]
# }
# response = requests.post(url, headers=headers, json=data)
# answer = response.json()['choices'][0]['message']['content']
# print(answer)

# make a request
response = client.messages.create(
    model=model,
    max_tokens=1000,
    messages=[
        {
            "role": "user",
            "content": "What is quantum computing? Answer in one sentence.",
        }
    ],
)
print(response.choices[0].message['content'])
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[14], line 35
#       6 headers = {
#       7     "Content-Type": "application/json",
#       8     "Authorization": api_key
#       9 }
#      10 # data = {
#      11 #     "model": "claude-sonnet-4-20250514",
#      12 #     "stream": False,
#    (...)
#      33
#      34 # make a request
# ---> 35 response = client.messages.create(
#      36     model=model,
#      37     max_tokens=1000,
#      38     messages=[
#      39         {
#      40             "role": "user",
#      41             "content": "What is quantum computing? Answer in one sentence.",
#      42         }
#      43     ],
#      44 )
#      45 print(response.choices[0].message['content'])
#
# File d:\Env\Python\lib\site-packages\anthropic\_utils\_utils.py:282, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     280             msg = f"Missing required argument: {quote(missing[0])}"
#     281     raise TypeError(msg)
# --> 282 return func(*args, **kwargs)
#
# File d:\Env\Python\lib\site-packages\anthropic\resources\messages\messages.py:930, in Messages.create(self, max_tokens, messages, model, metadata, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     923 if model in DEPRECATED_MODELS:
#     924     warnings.warn(
#     925         f"The model '{model}' is deprecated and will reach end-of-life on {DEPRECATED_MODELS[model]}.\nPlease migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.",
#     926         DeprecationWarning,
#     927         stacklevel=3,
#     928     )
# --> 930 return self._post(
#     931     "/v1/messages",
#     932     body=maybe_transform(
#     933         {
#     934             "max_tokens": max_tokens,
#     935             "messages": messages,
#     936             "model": model,
#     937             "metadata": metadata,
#     938             "service_tier": service_tier,
#     939             "stop_sequences": stop_sequences,
#     940             "stream": stream,
#     941             "system": system,
#     942             "temperature": temperature,
#     943             "thinking": thinking,
#     944             "tool_choice": tool_choice,
#     945             "tools": tools,
#     946             "top_k": top_k,
#     947             "top_p": top_p,
#     948         },
#     949         message_create_params.MessageCreateParamsStreaming
#     950         if stream
#     951         else message_create_params.MessageCreateParamsNonStreaming,
#     952     ),
#     953     options=make_request_options(
#     954         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     955     ),
#     956     cast_to=Message,
#     957     stream=stream or False,
#     958     stream_cls=Stream[RawMessageStreamEvent],
#     959 )
#
# File d:\Env\Python\lib\site-packages\anthropic\_base_client.py:1326, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1312 def post(
#    1313     self,
#    1314     path: str,
#    (...)
#    1321     stream_cls: type[_StreamT] | None = None,
#    1322 ) -> ResponseT | _StreamT:
#    1323     opts = FinalRequestOptions.construct(
#    1324         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1325     )
# -> 1326     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File d:\Env\Python\lib\site-packages\anthropic\_base_client.py:1114, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1111             err.response.read()
#    1113         log.debug("Re-raising status error")
# -> 1114         raise self._make_status_error_from_response(err.response) from None
#    1116     break
#    1118 assert response is not None, "could not resolve response (should never happen)"
#
# NotFoundError: Error code: 404 - {'error': {'message': 'Invalid URL (POST /v1/chat/completions/v1/messages)', 'localized_message': '', 'type': 'invalid_request_error', 'param': '', 'code': ''}}

# %%
def add_user_message(messages, content):
    messages.append({"role": "user", "content": content})

def add_assistant_message(messages, content):
    messages.append({"role": "assistant", "content": content})

def chat(messages):
    response = requests.post(url, headers=headers, json={
        "model": model,
        "stream": False,
        "messages": messages
    })
    answer = response.json()['choices'][0]['message']['content']
    return answer

# %%
# multi-turn conversation

# initialize messages
messages = []
# first user message
add_user_message(messages, "What is quantum computing? Answer in one sentence.")
# first chat response
answer = chat(messages)
# add assistant message
add_assistant_message(messages, answer)
# add second user message
add_user_message(messages, "Write another sentence.")
# second chat response
answer = chat(messages)
print(messages)
answer
# Out:
# [{'role': 'user', 'content': 'What is quantum computing? Answer in one sentence.'}, {'role': 'assistant', 'content': 'Quantum computing is a revolutionary computing approach that uses quantum mechanical phenomena like superposition and entanglement to process information in ways that can potentially solve certain complex problems exponentially faster than classical computers.'}, {'role': 'user', 'content': 'Write another sentence.'}]
# 'Quantum computers manipulate quantum bits (qubits) that can exist in multiple states simultaneously, unlike classical bits which are limited to either 0 or 1.'

# %%
# chat-bot end
messages = []
while  True:
    user_input = input("> ")
    print(">", user_input)
    if user_input.lower() in ["exit", "quit"]:
        print("Exiting chat.")
        break
    add_user_message(messages, user_input)
    answer = chat(messages)
    add_assistant_message(messages, answer)
    print("------")
    print("Bot:", answer)
    print("------")
# Out:
# > 1 + 1 = ?
# ------
# Bot: 1 + 1 = 2
# ------
# > Add 2 more ?
# ------
# Bot: 2 + 2 = 4
# ------
# > add the latest answer with 100
# ------
# Bot: 4 + 100 = 104
# ------
# > quit
# Exiting chat.
