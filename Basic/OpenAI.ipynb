# %%
from openai import OpenAI

client = OpenAI(
    api_key="sk-3fgfENhTtGOy1Z0B3aA17143EdC54dB7BeE78b3c63A8A6B3",
    base_url="https://api.laozhang.ai/v1"
)

# 基础对话
response = client.chat.completions.create(
    model="claude-3-5-sonnet-20241022",
    messages=[
        {
            "role": "system", 
            "content": "你是一个专业的AI助手，擅长分析和解决复杂问题"
        },
        {
            "role": "user", 
            "content": "请分析一下当前人工智能发展的主要趋势和挑战"
        }
    ],
    max_tokens=1000,
    temperature=0.7
)

print(response.choices[0].message.content)
# Out:
# # 当前人工智能发展的主要趋势和挑战
#
# ## 主要发展趋势
#
# ### 1. **大语言模型的持续演进**
# - **规模化发展**：模型参数量持续增长，能力不断提升
# - **多模态融合**：文本、图像、音频、视频的统一处理
# - **效率优化**：更小的模型实现更强的性能（如蒸馏、量化技术）
#
# ### 2. **AI应用的深度渗透**
# - **垂直领域专业化**：医疗、法律、金融等专业领域的深度应用
# - **企业级应用**：从客服、营销到研发全流程的AI赋能
# - **个人助手升级**：更智能、更个性化的日常辅助工具
#
# ### 3. **技术架构创新**
# - **Agent系统**：具备规划、工具使用和自主决策能力
# - **检索增强生成（RAG）**：结合知识库提升准确性
# - **小样本学习**：减少对大规模标注数据的依赖
#
# ### 4. **开源生态繁荣**
# - 开源模型质量显著提升
# - 社区驱动的快速迭代
# - 降低AI应用门槛
#
# ## 面临的主要挑战
#
# ### 1. **技术层面**
# - **幻觉问题**：模型生成不准确或虚构内容
# - **推理能力**：复杂逻辑推理仍有局限
# - **可解释性**：决策过程的透明度不足
# - **计算成本**：训练和部署需要大量资源
#
# ### 2. **伦理与安全**
# - **偏见与公平性**：训练数据中的偏见会被放大
# - **隐私保护**：数据使用与个人隐私的平衡
# - **深度伪造**：恶意使用AI生成虚假内容
# - **自主武器**：军事应用的伦理争议
#
# ### 3. **社会影响**
# - **就业冲击**：部分岗位被自动化替代
# - **数字鸿沟**：技术获取不平等加剧
# - **依赖性风险**：过度依赖AI决策的后果
# - **教育变革**：传统教育模式面临挑战
#
# ### 4. **监管与治理**
# - **法律滞后**：法规跟不上技术发展速度
# - **责任归属**：AI决策错误的问责机制
# - **国际协调**：跨国监管标准的统一
# - **知识产权**：AI生成内容的版权问题
#
# ## 未来展望
#
# **短期（1-2年）**：
# - 多模态能力成为标配
# - 企业级应用大规模落地
# - 监管框架逐步建立
#
# **中期（3-5年）**：
# - AGI（通用人工智能）雏形出现
# - AI与各行业深度融合
# - 新的商业模式和就业形态形成
#
# **长期（5年以上）**：
# - 人机协作成为常态
# - AI辅助科学发现加速
# - 社会结构可能发生根本性变化
#
# ## 建议
#
# 1. **技术研发**：关注可信AI、高效AI方向
# 2. **政策制定**：建立灵活且前瞻的监管体系
# 3. **教育培训**：培养AI
